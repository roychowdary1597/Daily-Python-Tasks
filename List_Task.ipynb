# %% [markdown]
#  ## Create an empty list numbers. Append 10, 20, and 30 to it. Then change the second element to 25 and print the updated list.
# >- Input:
# >- numbers = []
# >- Output:
# [10, 25, 30]

# %%
numbers = []
numbers.append(10)
numbers.append(20)
numbers.append(30)
numbers
# Out:
# [10, 20, 30]

# %%
numbers.pop(1)
# Out:
# 20

# %%
numbers.insert(1,25)
numbers
# Out:
# [10, 25, 30]

# %% [markdown]
# ## 2. Given a list colors, retrieve and print the first and last elements using indexing.
# >- Input:
# >- colors = ['red', 'blue', 'green', 'yellow']
# >- Output:
# >- red
# >- yellow

# %%
colors = ['red', 'blue', 'green', 'yellow']

# %%
colors[0]
# Out:
# 'red'

# %%
colors[3]
# Out:
# 'yellow'

# %% [markdown]
# ## 3. Slice the list fruits to extract only 'banana' and 'orange'.
# >- Input:
# >- fruits = ['apple', 'banana', 'orange', 'grapes', 'mango']
# >- Output:['banana', 'orange']

# %%
fruits = ['apple', 'banana', 'orange', 'grapes', 'mango']
fruits[1:3]
# Out:
# ['banana', 'orange']

# %% [markdown]
# ## 4. Reverse the given list using slicing.
# >- Input:
# >- numbers = [1, 2, 3, 4, 5]
# >- Output:[5, 4, 3, 2, 1]

# %%
numbers_4qn = [1, 2, 3, 4, 5]
numbers_4qn[ : :-1]
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 5. Count how many times 'apple' appears in the list.
# >- Input:
# >- fruits = ['apple', 'banana', 'apple', 'orange', 'apple']
# >- Output:3

# %%
fruits_cnt = ['apple', 'banana', 'apple', 'orange', 'apple']

# %%
fruits_cnt.count('apple')
# Out:
# 3

# %% [markdown]
# ## 6. Combine two lists into one.
# >- Input:
# >- list1 = [1, 2, 3]
# >- list2 = [4, 5, 6]
# >- Output:[1, 2, 3, 4, 5, 6]

# %%
list1 = [1, 2, 3]

# %%
list2 = [4, 5, 6]

# %%
print(list1,list2)
# Out:
# [1, 2, 3] [4, 5, 6]

# %%
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## 7. Insert 'watermelon' at index 2 in the list.
# >- Input:fruits = ['apple', 'banana', 'orange', 'mango']
# >- Output:['apple', 'banana', 'watermelon', 'orange', 'mango']

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'grapes', 'mango']

# %%
fruits_insert = ['apple', 'banana', 'orange', 'mango']

# %%
fruits_insert.insert(2,'watermelon')

# %%
print(fruits_insert)
# Out:
# ['apple', 'banana', 'watermelon', 'orange', 'mango']

# %% [markdown]
# ## 8. Remove 'orange' from the updated fruits list

# %%
fruits_insert
# Out:
# ['apple', 'banana', 'watermelon', 'orange', 'mango']

# %%
fruits_insert.remove('orange')

# %%
print(fruits_insert)
# Out:
# ['apple', 'banana', 'watermelon', 'mango']

# %% [markdown]
# ## 9. Remove the third element from the updated fruits list.

# %%
fruits_insert.pop(3)
# Out:
# 'mango'

# %%
print(fruits_insert)
# Out:
# ['apple', 'banana', 'watermelon']

# %% [markdown]
# ## 10. Access 6000 from the nested list.
# >- Input:
# >- nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# %%
nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# %%
element = nested_list[2][2][1]
print(element)
# Out:
# 6000

# %% [markdown]
# ## 11. Add 7000 after 6000 inside the nested list.
# >- Input:nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# >- Output:[10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
print(nested_list)
# Out:
# [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# %%
nested_list[2][2].append(7000)

# %%
nested_list
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ## 12. Replace the first occurrence of 20 with 200.
# >- Input:numbers = [5, 10, 15, 20, 25, 50, 20]
# >- Output:[5, 10, 15, 200, 25, 50, 20]

# %%
num = [5, 10, 15, 20, 25, 50, 20]

# %%
num.pop(3)
# Out:
# 20

# %%
num.insert(3,200)

# %%
print(num)
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %% [markdown]
# ## 13. Find the second-largest number in a list after removing duplicates.
# >- Input:numbers = [10, 20, 4, 45, 99, 99, 98]
# >- Output:98

# %%
nums = [10, 20, 4, 45, 99, 99, 98]

# %%
nums1 = sorted(set(nums),reverse = True)

# %%
nums1
# Out:
# [99, 98, 45, 20, 10, 4]

# %%
nums1[1]
# Out:
# 98
