# %% [markdown]
# ## 1. Write a Python program that accepts an integer from the user and determines whether it is a multiple of 3. Use an if-else statement to display the result.

# %%
num = int(input('Enter the number:'))
if num % 3 == 0:
    print(f'{num} is a mutiple of  3')
else:
    print(f'{num} is not a multiple of 3')
# Out:
# Enter the number: 7
# 7 is not a multiple of 3

# %% [markdown]
# ## 2. Create a program that asks the user to enter their age and nationality. Based on the input, use nested if statements to display a customized message, such as identifying if the user is a minor from a specific country.

# %%
age = int(input('Enter the age:'))
nationality = str(input('Enter the Nationality:'))
if age < 18:
    if nationality == 'India':
        print(f'You are Minor from {nationality}')
    else:
        print(f'You are Major from {nationality}')
# Out:
# Enter the age: 17
# Enter the Nationality: India
# You are Minor from India

# %% [markdown]
# ## 3. Develop a program that converts a student's numeric score into a letter grade based on a predefined grading scale (A, B, C, D, F). Use if-elif-else conditions to determine the corresponding grade.

# %%
score = float(input('Enter The Score:'))
if score >= 90:
    print('Grade : A')
elif score >= 80:
    print('Grade : B')
elif score >= 70:
    print('Grade : C')
elif score >= 60:
    print('Grade : D')
elif score >= 50:
    print('Grade : E')
else:
    print('Grade : Fail')
# Out:
# Enter The Score: 85
# Grade : B

# %% [markdown]
# ## 4. Write a Python script that checks if a given year is a leap year. The program should consider the rules for leap years: divisible by 4, not divisible by 100 unless also divisible by 400.

# %%
year = int(input('Enter the Year:'))
if (year % 4 == 0 and year % 100 != 0):
    print(f'{year} Was a leap year')
elif (year % 400 == 0):
    print(f'{year} Was a leap year')
else:
    print(f'{year} Was not a leap year')
# Out:
# Enter the Year: 2023
# 2023 Was not a leap year

# %% [markdown]
# ## 5. Create a BMI calculator that accepts a person's height (in meters) and weight (in kilograms), calculates the BMI, and categorizes it as Underweight, Normal, Overweight, or Obese using predefined thresholds.
# >- Input:
# >- Enter weight (kg): 70
# >- Enter height (m): 1.75
# >- Output:Your BMI is 22.9 - Normal weight.

# %%
weight = float(input('Enter The weight in KG:'))
height = float(input('Enter the height in meters:'))
bmi = weight / height ** 2
if bmi <= 20:
    print(f'Your BMI is {bmi} - Under Weight ')
elif bmi > 20 and bmi <= 25:
    print(f'Your BMI is {bmi} - Normal Weight ')
else:
    print(f'Your BMI is {bmi} - over Weight ')
# Out:
# Enter The weight in KG: 70
# Enter the height in meters: 1.75
# Your BMI is 22.857142857142858 - Normal Weight

# %% [markdown]
# ## 6. Build a program that presents a menu for basic arithmetic operations (addition, subtraction, multiplication, and division). The user should enter two numbers and choose an operation, after which the program will display the computed result.
#
#     Input:
#     Select operation:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     Enter choice (1/2/3/4): 3
#     Enter first number: 6
#     Enter second number: 4

# %%
a = int(input("Enter the value for A:"))
b = int(input("Enter the value for B:"))
symbol = input("Enter the mentioned Symbol for Arthimetic Operation (+, -, /, *):")
if symbol == '+':
    result = a + b
    print(result)
elif symbol == '-':
    result =  a - b
    print(result)
elif symbol == '*':
    result = a * b
    print(result)
elif symbol == '/':
    result = a / b
    print(result)
else:
    pass
# Out:
# Enter the value for A: 6
# Enter the value for B: 4
# Enter the mentioned Symbol for Arthimetic Operation (+, -, /, *): *
# 24

# %% [markdown]
# ## 7. Develop a program that allows users to convert temperatures between Celsius and Fahrenheit. The user should specify the conversion direction and input a temperature value to receive the converted result.
#     Input:
#     Choose conversion:
#     1. Celsius to Fahrenheit
#     2. Fahrenheit to Celsius
#     Enter choice (1/2): 1
#     Enter temperature in Celsius: 25
#     Output:
#     25°C is equal to 77°F.

# %%
choice = int(input('Enter The conversion Choice(1 or 2):'))
if choice == 1:
    celsius_temp = float(input('Enter the Value in °C:'))
    f = (9/5 * celsius_temp) + 32
    print(f'{celsius_temp}°C is equal to {f}°F')
elif choice == 2:
    faren_temp = float(input('Enter the Value in °C:'))
    c = 5/9 * (faren_temp - 32)
    print(f'{faren_temp}°F is equal to {c}°C')
else:
    pass
# Out:
# Enter The conversion Choice(1 or 2): 1
# Enter the Value in °C: 25
# 25.0°C is equal to 77.0°F

# %% [markdown]
# ## 8. Write a Python program that takes a user-inputted password and evaluates its strength based on the presence of uppercase letters, lowercase letters, numbers, and special characters.
#     Input1:
#     Enter your password: StrongPass123!
#     Output1:
#     Password Strength: Strong
#     Input2:
#     Enter your password: weakpass
#     Output2:
#     Password Strength: Weak

# %%
password = input('Enter The Password:')
strength = 0
if len(password)>= 8:
    strength += 1
if any(c.isupper() for c in password):
    strength += 1
if any(c.islower() for c in password):
    strength += 1
if any(c.isdigit() for c in password):
    strength += 1
if any ('@'or'_' in password):
    strength += 1
if strength >= 3:
    print('Strong Password')
elif strength < 3 :
    print('Weak Password')
else:
    pass
# Out:
# Enter The Password: roy@1345
# Strong Password

# %% [markdown]
# ## 9. Create a Python program that simulates an inventory management system. The system should allow the user to add items, update their quantity, remove items, and display the inventory using a dictionary.
#
#     Input :
#
#     Choose an operation:
#     1. Add Item
#     2. Update Quantity
#     3. Remove Item
#     4. Display Inventory
#
#     Enter your choice: 1
#     Enter item name: Laptop
#     Enter quantity: 5

# %%
##### inventry = {}
print(' 1. Add Item \n 2. Update Quantity \n 3.remove Item \n 4.Display Inventory')
choice1 = int(input('Enter The Choice(1,2,3,4):'))
if choice1 == 1:
    item = input('Item name:')
    qty = input('Quantity:')
    inventry[item] = qty
    print(f'{item} was Added')
elif choice1 == 2:
    item = input("Item name: ")
    if item in inventory:
        new_qty = int(input("New quantity: "))
        inventory[item] = new_qty
        print(f"{item} updated!")
    else:
        print("Item not found")
elif choice1 == 3:
    item = input("Item to remove: ")
    if item in inventory:
        del inventory[item]
        print(f"{item} removed!")
    else:
        print("Item not found")
elif choice == '4':
    print("\nCurrent Inventory:")
    for item, qty in inventory.items():
        print(f"{item}: {qty}")
else: 
    print('Inavaloid Choice')
# Out:
#  1. Add Item
#  2. Update Quantity
#  3.remove Item
#  4.Display Inventory
# Enter The Choice(1,2,3,4): 1
# Item name: Laptop
# Quantity: 5
# Laptop was Added
