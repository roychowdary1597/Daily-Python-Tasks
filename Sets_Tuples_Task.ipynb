# %% [markdown]
# # Section 1 - Sets

# %% [markdown]
# ## 1)Create a Python set containing the first 10 even numbers {2, 4, 6,8,10}. Write a program to display this set.

# %%
my_set = {2, 4, 6, 8,10}
print(my_set)
# Out:
# {2, 4, 6, 8, 10}

# %% [markdown]
# ## 2)Set Operations Given two sets, write a Python program to find the union, intersection, and difference of these sets.

# %%
set1 = {10,20,30,40,50}
set1
# Out:
# {10, 20, 30, 40, 50}

# %%
set2 = {30,40,50,60,70}
set2
# Out:
# {30, 40, 50, 60, 70}

# %%
# union
print(set1.union(set2))
# Out:
# {70, 40, 10, 50, 20, 60, 30}

# %%
#intersection
print(set1.intersection(set2))
# Out:
# {40, 50, 30}

# %%
#difference
print(set1.difference(set2))
# Out:
# {10, 20}

# %% [markdown]
# ## Set Operations and Methods Write a Python program that takes a set of numbers and performs the following operations:
# >- Add a new number to the set.
# >- Remove a number from the set.
# >- Check if a specific number is in the set.
# >- Find the size of the set.

# %%
set3 = {1, 2, 3, 4, 5, 6, 7}
print(set3)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#add
set3.add(8)

# %%
print(set3)
# Out:
# {1, 2, 3, 5, 6, 7, 8}

# %%
#remove
set3.remove(4)

# %%
print(set3)
# Out:
# {1, 2, 3, 5, 6, 7, 8}

# %%
#specific number
if 5 in set3:
    print('Number is found')
# Out:
# Number is found

# %%
# size of set

# %%
print(len(set3))
# Out:
# 7

# %% [markdown]
# ## Set Operations with Lists Create a Python list with duplicate elements and convert it into a set to remove duplicates. Then, write a program to count how many duplicates were removed

# %%
list1 = [20,80,20,40,50,80,40,20]

# %%
set4 = set(list1)

# %%
set4
# Out:
# {20, 40, 50, 80}

# %%
duplicates = len(list1) - len(set4)

# %%
print(f'The number duplicates that were removed are :{duplicates}')
# Out:
# The number duplicates that were removed are :4

# %% [markdown]
# ## Describe Set and properties of Set with examples

# %% [raw]
# Set is a one of the four data structures and they are stored in { } or also in the form of type casting method that is
# set_1 = set(elements1, .....)
# The properties are
# 1) It does not allow duplicates
# 2)sets are unodered
# 3) set elements  can be added are removed

# %% [markdown]
# # Section 2

# %% [markdown]
# ## 1) Create a Python tuple containing the names of your favorite fruits. Write a Python program to print each fruit name from the tuple.

# %%
tup1 = ('Apple','Mango','Watermelon','Cherries')

# %%
print(tup1)
# Out:
# ('Apple', 'Mango', 'Watermelon', 'Cherries')

# %% [markdown]
# ## 2)Tuple Operations Given two tuples, write a Python program to concatenate them into a single tuple and then find the length of the resulting tuple.

# %%
tup2 = ('Zoom','Google','Meet','Email','Browser')

# %%
print(tup1)
# Out:
# ('Apple', 'Mango', 'Watermelon', 'Cherries')

# %%
lst1 = list(tup1)
print(lst1)
# Out:
# ['Apple', 'Mango', 'Watermelon', 'Cherries']

# %%
lst2 = list(tup2)
print(lst2)
# Out:
# ['Zoom', 'Google', 'Meet', 'Email', 'Browser']

# %%
lst1.extend(lst2)

# %%
print(lst1)
# Out:
# ['Apple', 'Mango', 'Watermelon', 'Cherries', 'Zoom', 'Google', 'Meet', 'Email', 'Browser']

# %%
tup3 = tuple(lst1)

# %%
print(tup3)
# Out:
# ('Apple', 'Mango', 'Watermelon', 'Cherries', 'Zoom', 'Google', 'Meet', 'Email', 'Browser')

# %%
print(len(tup3))
# Out:
# 9

# %% [markdown]
# ## 3) Tuple and Set Conversion Write a Python program that takes a tuple of integers and converts it into a set. Then, find and print the maximum and minimum value from the set

# %%
tup4 = (9,0,4,59,98,67,1,2)

# %%
set6 = set(tup4)

# %%
print(set6)
# Out:
# {0, 1, 98, 67, 4, 2, 9, 59}

# %%
minValue = min(set6)

# %%
maxValue = max(set6)

# %%
print('The Minimum Value is :',minValue)
print('The Maximum Value is :',maxValue)
# Out:
# The Minimum Value is : 0
# The Maximum Value is : 98

# %% [markdown]
# ## 4) Tuple Immutability Explain the concept of immutability in Python tuples with examples. Discuss why tuples are considered immutable data structures.

# %% [raw]
# Immutability means once the tuple has been created then the tuple cannot be updated or added or removed compared to Lists and it results with an Error
# Explaining with an example :

# %%
my_tup = (1,4,6,7,8)

# %%
my_tup.append(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 my_tup.append(9)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [raw]
# Tuple is immutable because of its safety and fixed size

# %% [markdown]
# ## 5)Tuple Slicing Given a tuple of 10 elements, write a Python program to print the elements from the 3rd to the 7th position using slicing.

# %%
tup3
# Out:
# ('Apple',
#  'Mango',
#  'Watermelon',
#  'Cherries',
#  'Zoom',
#  'Google',
#  'Meet',
#  'Email',
#  'Browser')

# %%
tup3[3:8]
# Out:
# ('Cherries', 'Zoom', 'Google', 'Meet', 'Email')

# %% [markdown]
# ## 6)Tuple and Set Combinations Create a tuple containing the names of your friend's favorite movies and a set containing the names of your favorite movies. Write a Python program to find and display common elements

# %%
friend1 = ('Mad','DJ-TillU','Devara','KGF','Sahoo')

# %%
friend2 = ('Bahubali','Agent','Daaku-Maharaj','Mad','DJ-TillU')

# %%
mySet = set(friend1)

# %%
mySet1 = set(friend2)

# %%
new = mySet.intersection(mySet1)

# %%
print(new)
# Out:
# {'DJ-TillU', 'Mad'}

# %%
commom = tuple(new)
print(commom)
# Out:
# ('DJ-TillU', 'Mad')

# %% [markdown]
# ## 7) tup=(1,2,3,2,4,5,3,4,2). Count the occurrences of element ‘2’ in the given tuple.

# %%
tp1 = (1,2,3,2,4,5,3,4,2)

# %%
print(tp1.count(2))
# Out:
# 3

# %% [markdown]
# ## Access value 20 from the tuple,
# ##### tuple1 = ("Orange", [10, 20, 30], (5, 15, 25))

# %%
tuple1 = ("Orange", [10, 20, 30], (5, 15, 25))

# %%
tuple1[1][1]
# Out:
# 20

# %% [markdown]
# ## 9) Create a dictionary with key-value pairs for a person's name and age.
# >- Add a new key-value pair "city" with the value "Delhi" to the person dictionary.
# >- Remove the key-value pair with the key "age" from the person dictionary.
# >- Sort the person's dictionary by its keys.

# %%
dict1 = {'Name':'Rajiv','Age':21}

# %%
dict1.update({'City':'Delhi'})

# %%
dict1
# Out:
# {'Name': 'Rajiv', 'Age': 21, 'City': 'Delhi'}

# %%
dict1.pop('Age')
# Out:
# 21

# %%
dict1
# Out:
# {'Name': 'Rajiv', 'City': 'Delhi'}

# %%
sorted_person = dict(sorted(dict1.items()))

# %%
print(sorted_person)
# Out:
# {'City': 'Delhi', 'Name': 'Rajiv'}
