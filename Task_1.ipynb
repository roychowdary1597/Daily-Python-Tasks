# %% [markdown]
# # Task_1

# %% [markdown]
# # Section 1

# %% [markdown]
# ## (1) Run the given identifiers and categorize them into valid and invalid ones.

# %% [markdown]
# ### Valid Identifiers

# %%
my_variable = 25

# %%
counter = 40.7

# %%
_total = "Hello"

# %%
Name123 = 136

# %%
myFunction = True

# %%
_data = False

# %% [markdown]
# ### Invalid Identifiers

# %%
123abc = 34
# Out:
#   Cell In[42], line 1
#     123abc = 34
#       ^
# SyntaxError: invalid decimal literal

# %%
my variable =6.7
# Out:
#   Cell In[46], line 1
#     my variable =6.7
#        ^
# SyntaxError: invalid syntax

# %%
@count = "hi"
# Out:
#   Cell In[44], line 1
#     @count = "hi"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
for = "True"
# Out:
#   Cell In[36], line 1
#     for = "True"
#         ^
# SyntaxError: invalid syntax

# %%
if_condition? = "Innomatics"
# Out:
#   Cell In[38], line 1
#     if_condition? = "Innomatics"
#                 ^
# SyntaxError: invalid syntax

# %%
class = "Hyderabad"
# Out:
#   Cell In[40], line 1
#     class = "Hyderabad"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## (2)Explain why Python treats some identifiers as invalid.

# %% [raw]
# #There are some set of rules for the identifiers
# 1)It Should not Start with the Numbers or any special Characters but it can start with underscore(_)
# 2)It should not Start with keywords or reserved Words
# 3)identifiers are case sensitive

# %% [markdown]
# ### (3)Rewrite the invalid identifiers correctly.

# %%
abc123 = 34

# %%
my_variable = 6.7

# %%
count = "hi"

# %%
for_each = "True"

# %%
if_condition = "Innomatics"

# %%
class_conducted = "Hyderabad"

# %% [markdown]
# ### (4)Assign different valid identifiers to given values.

# %%
var_1 = 10

# %%
var_2 = -5

# %%
var_3 = 3.14159

# %%
var_4 = -0.12345

# %%
var_5 = 1000

# %%
var_6 = "Hello, World!"

# %%
var_7 = "Python"

# %%
var_8 = "I am learning"

# %%
var_9 = "Text type"

# %%
var_10 = "String"

# %%
var_11 = True

# %%
var_12 = False

# %% [markdown]
# # Section 2

# %% [markdown]
# ## (1)Define two variables and perform operations using arithmetic operators (+, -, *, /, //, %, **).

# %%
Value1 = 10
Value2 = 15

# %%
op1 = Value1 + Value2 
print(op1)
# Out:
# 25

# %%
op2 = Value1 - Value2
print(op2)
# Out:
# -5

# %%
op3 = Value1 * Value2
print(op3)
# Out:
# 150

# %%
op4 = Value1 / Value2
print(op4)
# Out:
# 0.6666666666666666

# %%
op5 = Value1 // Value2
print(op5)
# Out:
# 0

# %%
op6 = Value1 % Value2
print(op6)
# Out:
# 10

# %%
op7 = Value1 ** Value2
print(op7)
# Out:
# 1000000000000000

# %% [markdown]
# ## (2)You have a floor that is 95 meters long and 58.8 meter wide. Find out the total area using python and print it.

# %%
length1 = 95

# %%
width1 = 58.8

# %%
total_area = length1 * width1
print(f'The total area of the floor was about {total_area} long')
# Out:
# The total area of the floor was about 5586.0 long

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# ### (1)Create a Python script that defines two boolean variables, is_sunny and is_warm, with appropriate values (True or False).

# %%
is_sunny = True
is_warm = False

# %% [markdown]
# ## (2)Use logical operators (and, or, not) to create the following conditions:
# #####      Check if it's both sunny and warm and print the result.
# #####      Check if it's either sunny or warm and print the result.
# #####         Check if it's not sunny and print the result.

# %%
is_sunny and is_warm
# Out:
# False

# %%
is_sunny or is_warm
# Out:
# True

# %%
not is_sunny
# Out:
# False

# %% [markdown]
# # Comparision Operators

# %% [markdown]
# ## (1)Create a Python script that defines two variables, value1 and value2, with any numeric values.

# %%
value1 = 20

# %%
value2 = 40

# %% [markdown]
# ## (2)Use comparative operators (==, !=, <, >, <=, >=) to create the following conditions:
# #### Check if value1 is equal to value2 and print the result.
# #### Check if value1 is less than value2 and print the result.
# #### Check if value1 is greater than value2 and print the result.
# #### Check if value1 is less than or equal to value2 and print the result.
# #### Check if value1 is greater than or equal to value2 and print the result.

# %%
value1 == value2
# Out:
# False

# %%
value1 < value2
# Out:
# True

# %%
value1 > value2
# Out:
# False

# %%
value1 <= value2
# Out:
# True

# %%
value1 >= value2
# Out:
# False
