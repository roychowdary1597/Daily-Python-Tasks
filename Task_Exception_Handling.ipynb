# %% [markdown]
# ## 1. Create a Function to Read a File and Handle File Not Found Error.
#     Objective:
#     Write a function that attempts to read a file and handles the error if the file doesn’t exist.
#     Sample Input:
#     def read_file_safe(filename):
#          Try to read the file, handle FileNotFoundError
#     Expected Output (if file doesn’t exist):
#     Example:
#     Error: File not found.

# %%
def read_file_name(filename):
    try:
        with open(filename,'r') as f:
            f.read()
            print(f)
    except FileNotFoundError as e:
        print(e,': File Not Found')

# %%
read_file_name('Handle.txt')
# Out:
# [Errno 2] No such file or directory: 'Handle.txt' : File Not Found

# %% [markdown]
# ## 2. Create a Function to Divide Two Numbers and Handle Division by Zero
#     Objective:
#      Write a function that divides two numbers and handles the ZeroDivisionError.
#     Sample Input:
#     def safe_divide(a, b):
#         # Divide a by b
#     Expected Output (if b = 0):
#     Error: Cannot divide by zero.

# %%
def safe_divide(a, b):
    try:
        c = a / b
        print(c)
    except ZeroDivisionError as i:
        print(i,': Cannot be divided by zero')

# %%
safe_divide(5,0)
# Out:
# division by zero : Cannot be divided by zero

# %% [markdown]
# ## 3. Handle ValueError When Converting Input to Integer
#     Objective:
#      Take input from the user and convert it to an integer. Handle the error if the input is not a number.
#     Sample Input:
#     def convert_to_int():
#         # Convert user input to int
#
#     Expected Output:
#     Enter a number: abc
#     Error: Invalid input. Please enter a number.

# %%
def convert_to_int():
    try:
        convert = int(input('Enter a Number:'))
        print(convert)
    except ValueError as v:
        print(v,':Invalid Input. Please Enter a Number')

# %%
convert_to_int()
# Out:
# Enter a Number: 45
# 45

# %% [markdown]
# ## 4. Handle Multiple Exceptions in a Function
#     Objective:
#      Create a function that performs division and handles both ValueError and ZeroDivisionError.
#     Sample Input:
#     def robust_division():
#         # Get input and divide safely
#
#     Expected Output:
#     Enter numerator: ten
#     Error: Please enter a valid number.
#
#     Enter denominator: 0
#     Error: Cannot divide by zero.

# %%
def robust_division():
    try:
        num = int(input('Enter Numerator:'))
        den = int(input('Enter denominator:'))
        d = num / den
        print('the Result is:',d)
    except ValueError as nm:
        print(nm,'Please Enter a Valid Number')
    except ZeroDivisionError as dm:
        print(dm,':Cannot be divide by Zero')

# %%
robust_division()
# Out:
# Enter Numerator: 45
# Enter denominator: 45
# the Result is: 1.0

# %%
robust_division()
# Out:
# Enter Numerator: 45
# Enter denominator: 45
# the Result is: 1.0

# %% [markdown]
# ## 5. Use finally Block to Always Print a Message
#     Objective:
#      Demonstrate the use of finally to execute code regardless of an exception occurring.
#     Sample Input:
#     def demonstrate_finally():
#         # Try something risky
#
#     Expected Output:
#     Error occurred: something went wrong.
#     This will always run!

# %%
def demonstrate_finally():
    try:
        dd = int(input('Enter Number:'))
        if dd < 16 and dd > 1:
            dd += 1
            print(dd)
    except ValueError as ve:
        print('Error occurred: something went wrong.',ve)

    finally:
        print('This will Always run')

# %%
demonstrate_finally()
# Out:
# This will Always run
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 demonstrate_finally()
#
# Cell In[15], line 3, in demonstrate_finally()
#       1 def demonstrate_finally():
#       2     try:
# ----> 3         dd = int(input('Enter Number:'))
#       4         if dd < 16 and dd > 1:
#       5             dd += 1
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## 6. Create a Custom Exception Class and Raise It
#     Objective:
#      Create a custom exception called NegativeNumberError that gets raised when a negative number is passed to a function.
#     Write a function check_positive(num) that:
#
#     Raises NegativeNumberError if num is less than 0
#     Prints "Number is positive." if the number is non-negative
#     Catches and displays the custom error message when raised
#     Sample Input:
#     check_positive(-10)
#
#     Expected Output:
#     Custom Error: Negative numbers are not allowed!

# %%
class CustomException(Exception):
    def __init__(self,num,error_name = "Dont provide Negative Values"):
        self.num = num
        self.error_name = error_name
        super().__init__(self.error_name)
    
    def display_error_name(self):
        return f"{self.error_name}, {num}"

# %%
num = -10
try:
    if num < 0:
        raise CustomException(num)
except CustomException as e:
    print(f"Error: {e}")
# Out:
# Error: Dont provide Negative Values

# %%
class NegativeNumberError(Exception):
    def __init__ (self,message = 'Negative Numbers are not allowed'):
        self.message = message
        super().__init__(self.message)
def check_positive(num):
    try:
        if num < 0:
            raise NegativeNumberError()
        print('Number is Positive')
    except NegativeNumberError as e:
        print('Custom Error:',e)

# %%
check_positive(-4)
# Out:
# Custom Error: Negative Numbers are not allowed

# %% [markdown]
# ## 7. What is AssertionError ? Use assert to Validate Input.
#     Objective:
#     Use assert to check if age is above 0. If the age is not positive, raise an AssertionError with the message: "Age must be positive!"
#     Sample Input:
#     check_age(-5)
#
#     Expected Output:
#     Assertion Error: Age must be positive!

# %% [raw]
# The assert keyword lets you test if a condition in your code returns True, if not, the program will raise an AssertionError.

# %%
def check_age(age):
    try:
        assert age > 0 , 'Age Must be positive'
        print('Age is Negative')
    except AssertionError as ae:
        print('Assertion Error:',ae)

# %%
check_age(-5)
# Out:
# Assertion Error: Age Must be positive

# %% [markdown]
# ## 8. Handle File Reading with Try-Except-Finally
#     Objective:
#      Try to read a file, handle any exceptions (like file not found), and always ensure the file is closed using a finally block.
#     Sample Input:
#     read_file_with_cleanup("nonexistent.txt")
#
#     Expected Output:
#     File not found.
#     Cleaning up...

# %%
def read_file_with_cleanup(filename):
    file = None
    try:
        with open(filename,'r') as f:
            content = file.read()
            print(content)
    except FileNotFoundError as fe:
        print('File Not found.')
    finally:
        if file:
            file.close()
        print('Cleaning Up....')

# %%
read_file_with_cleanup('contro.txt')
# Out:
# File Not found.
# Cleaning Up....

# %% [markdown]
# ## 9. Handle TypeError in Function Arguments
#     Objective:
#      Create a function that adds two numbers and gracefully handles TypeError if types are incompatible.
#     Sample Input:
#     safe_add("5", 6)
#
#     Expected Output (if a = "5" and b = 6):
#     TypeError: unsupported operand type(s)
#     Error: Both inputs must be numbers.

# %%
def safe_add(a,b):
    try:
        type(a) == type(b)
        c = a + b
        print(c)
    except TypeError as ee:
        print('Error : Both Inputs Must be numbers',ee)

# %%
safe_add('5',6)
# Out:
# Error : Both Inputs Must be numbers can only concatenate str (not "int") to str

# %% [markdown]
# ## 10. Create a Try-Except Block That Logs Errors to a File
#     Objective:
#      Write code that captures exceptions and logs them into a file called (error_log.txt) instead of printing them to the console.
#     Sample Input:
#     error_logger()
#
#     Expected Output in error_log.txt:
#     division by zero

# %%
def error_logger(a,b):
    try:
        c = a / b
        print(c)
    except ZeroDivisionError as ee:
        with open('EXPHAND.txt','a') as file:
            file.write(str(ee) +'\n')
    finally:
        with open('EXPHAND.txt','r') as f:
            content = f.read()
            print(content)

# %%
error_logger(5,0)
# Out:
# division by zero
# division by zero
